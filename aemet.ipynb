# %%
import requests
import json

# --- Configuration (IMPORTANT: Replace with your AEMET API key if different!) ---
# Your AEMET API key.
AEMET_API_KEY = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJmcnZhcmdhcy44N0BnbWFpbC5jb20iLCJqdGkiOiI3MTJmNjFkYi1hMDg3LTRkM2QtODFlNS04ZjY4YjYwOWE2YTAiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTc0OTIyOTY1OSwidXNlcklkIjoiNzEyZjYxZGItYTA4Ny00ZDNkLTgxZTUtOGY2OGI2MDlhNmEwIiwicm9sZSI6IiJ9.BbMqB0Jj2_z5wJw6luQhH7iMlJDMk2gfPEVOQ7Chc7E'

# Municipality code for Barcelona
BARCELONA_MUNICIPALITY_CODE = '08019'

# Initial URL for the hourly prediction endpoint
INITIAL_API_URL = f'https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/horaria/{BARCELONA_MUNICIPALITY_CODE}'

# Headers for the HTTP request, including your API key
HEADERS = {
    'accept': 'application/json',
    'api_key': AEMET_API_KEY
}

# --- Data Retrieval Process ---
print(f"Starting to fetch hourly prediction for Barcelona ({BARCELONA_MUNICIPALITY_CODE})...")

try:
    # Step 1: Make the initial request to get the URL pointing to the actual data
    print(f"1. Making the first call to: {INITIAL_API_URL}")
    initial_response = requests.get(INITIAL_API_URL, headers=HEADERS)
    initial_response.raise_for_status() # Raises an HTTPError for bad responses (4xx or 5xx)
    
    # Parse the first JSON response
    data_info = initial_response.json()

    # Check if the 'datos' key exists and contains the data URL
    if 'datos' in data_info:
        data_url = data_info['datos']
        print(f"2. Data URL obtained: {data_url}")

        # Step 2: Make the request to the actual data URL
        print("3. Fetching final hourly prediction data...")
        final_data_response = requests.get(data_url)
        final_data_response.raise_for_status() # Raises an HTTPError for bad responses
        
        # Parse the final prediction data
        hourly_prediction_data = final_data_response.json()
        
        # --- Display the Data ---
        print(f"\n--- Hourly Prediction for Barcelona ({BARCELONA_MUNICIPALITY_CODE}) ---")
        # Hourly predictions for municipalities usually come as a list of dictionaries.
        # Print the entire structure for detailed review.
        print(json.dumps(hourly_prediction_data, indent=2, ensure_ascii=False))

    else:
        print("\nError: The initial AEMET response did not contain the 'datos' URL.")
        print(f"Full initial response content: {json.dumps(data_info, indent=2, ensure_ascii=False)}")

except requests.exceptions.RequestException as e:
    # Catch any request-related errors (connection, timeouts, HTTP errors)
    print(f"\nRequest Error! An issue occurred with the network or HTTP request: {e}")
    if hasattr(e, 'response') and e.response is not None:
        print(f"HTTP Status Code: {e.response.status_code}")
        print(f"Error Response Content: {e.response.text}")
    print("Please ensure your API key is correct and you have an active internet connection.")

except json.JSONDecodeError as e:
    # Catch errors if the response is not valid JSON
    print(f"\nJSON Decode Error! The response was not valid JSON: {e}")

except Exception as e:
    # Catch any other unexpected errors
    print(f"\nAn unexpected error occurred!: {e}")
# Out:
# Starting to fetch hourly prediction for Barcelona (08019)...
# 1. Making the first call to: https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/horaria/08019
# 2. Data URL obtained: https://opendata.aemet.es/opendata/sh/051a2dbf
# 3. Fetching final hourly prediction data...
#
# --- Hourly Prediction for Barcelona (08019) ---
# [
#   {
#     "origen": {
#       "productor": "Agencia Estatal de Meteorología - AEMET. Gobierno de España",
#       "web": "https://www.aemet.es",
#       "enlace": "https://www.aemet.es/es/eltiempo/prediccion/municipios/horas/barcelona-id08019",
#       "language": "es",
#       "copyright": "© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.",
#       "notaLegal": "https://www.aemet.es/es/nota_legal"
#     },
#     "elaborado": "2025-06-12T12:06:06",
#     "nombre": "Barcelona",
#     "provincia": "Barcelona",
#     "prediccion": {
#       "dia": [
#         {
# ...

# %%
hourly_prediction_data= spark.createDataFrame(hourly_prediction_data)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hourly_prediction_data= spark.createDataFrame(hourly_prediction_data)
#
# File c:\Users\varga\.virtualenvs\TravelMind-D0cwe-Yj\Lib\site-packages\pyspark\sql\session.py:1443, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1438 if has_pandas and isinstance(data, pd.DataFrame):
#    1439     # Create a DataFrame from pandas DataFrame.
#    1440     return super(SparkSession, self).createDataFrame(  # type: ignore[call-overload]
#    1441         data, schema, samplingRatio, verifySchema
#    1442     )
# -> 1443 return self._create_dataframe(
#    1444     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#    1445 )
#
# ...

# %%
import requests
import json
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType, ArrayType, DateType
import datetime

# --- Configuración (¡IMPORTANTE: Reemplaza con tu clave API de AEMET si es diferente!) ---
# Tu clave API de AEMET.
AEMET_API_KEY = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJmcnZhcmdhcy44N0BnbWFpbC5jb20iLCJqdGkiOiI3MTJmNjFkYi1hMDg3LTRkM2QtODFlNS04ZjY4YjYwOWE2YTAiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTc0OTIyOTY1OSwidXNlcklkIjoiNzEyZjYxZGItYTA4Ny00ZDNkLTgxZTUtOGY2OGI2MDlhNmEwIiwicm9sZSI6IiJ9.BbMqB0Jj2_z5wJw6luQhH7iMlJDMk2gfPEVOQ7Chc7E'
# Código del municipio para Barcelona
BARCELONA_MUNICIPALITY_CODE = '08019'

def get_aemet_hourly_prediction_as_spark_df(api_key, municipality_code):
    """
    Obtiene la predicción horaria para un municipio de la API de AEMET
    y la convierte en un DataFrame de Spark.

    Args:
        api_key (str): Tu clave de API de AEMET.
        municipality_code (str): El código del municipio (ej. '08019' para Barcelona).

    Returns:
        pyspark.sql.DataFrame: Un DataFrame de Spark con los datos de predicción horaria,
                               o None si ocurre un error o no hay datos.
    """
    
    # Construir la URL inicial de la API
    initial_api_url = f'https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/horaria/{municipality_code}'
    
    headers = {
        'accept': 'application/json',
        'api_key': api_key
    }

    try:
        print(f"1. Realizando la primera llamada a la API para el municipio {municipality_code}...")
        initial_response = requests.get(initial_api_url, headers=headers)
        initial_response.raise_for_status() # Lanza una excepción para errores HTTP
        
        data_info = initial_response.json()

        if 'datos' in data_info:
            data_url = data_info['datos']
            print(f"2. URL de datos obtenida: {data_url}")

            print("3. Obteniendo los datos de predicción horaria...")
            final_data_response = requests.get(data_url)
            final_data_response.raise_for_status() # Lanza una excepción para errores HTTP
            
            raw_prediction_data = final_data_response.json()

            # --- Inicializar SparkSession ---
            # Solo si no hay una sesión activa, para evitar errores en Colab.
            try:
                spark = SparkSession.builder.appName("AEMETHourlyPrediction").getOrCreate()
                print("SparkSession inicializada.")
            except Exception as e:
                print(f"Error al inicializar SparkSession: {e}")
                return None
            
            # Los datos de AEMET para predicciones horarias de municipios vienen como
            # una lista de diccionarios, donde cada diccionario contiene la predicción para un día.
            # Necesitamos aplanar esto si queremos un DataFrame más manejable por hora.

            # Asegurarse de que raw_prediction_data es una lista y no está vacía
            if not isinstance(raw_prediction_data, list) or not raw_prediction_data:
                print("Error: El formato de los datos de predicción no es el esperado (lista vacía o no lista).")
                return None
            
            # El primer elemento de la lista contiene los datos de la predicción para el municipio
            municipio_data = raw_prediction_data[0]

            # Vamos a extraer los datos horarios
            hourly_records = []
            
            # La predicción horaria está bajo 'prediccion', que es una lista de días
            for day_data in municipio_data.get('prediccion', []):
                fecha = day_data.get('fecha') # Formato 'YYYY-MM-DD'
                
                # Iterar sobre los datos horarios de cada día
                for hora_temp in day_data.get('temperatura', []):
                    record = {
                        'municipio_id': municipio_data.get('id'),
                        'nombre_municipio': municipio_data.get('nombre'),
                        'provincia': municipio_data.get('provincia'),
                        'fecha': fecha,
                        'hora': hora_temp.get('periodo'), # Hora en formato 'HH'
                        'temperatura': hora_temp.get('valor')
                    }
                    # Añadir otros campos si existen y queremos incluirlos
                    # Este es un ejemplo básico. Un esquema completo sería más complejo.
                    
                    # Buscar precipitacion
                    for prec in day_data.get('precipitacion', []):
                        if prec.get('periodo') == record['hora']:
                            record['precipitacion'] = prec.get('valor')
                            break
                    else: # Si no se encontró precipitación para esa hora
                        record['precipitacion'] = None

                    # Buscar viento
                    for viento in day_data.get('viento', []):
                        if viento.get('periodo') == record['hora']:
                            record['dir_viento'] = viento.get('direccion')
                            record['vel_viento'] = viento.get('velocidad')
                            break
                    else:
                        record['dir_viento'] = None
                        record['vel_viento'] = None

                    # Buscar racha maxima
                    for racha in day_data.get('rachaMax', []):
                        if racha.get('periodo') == record['hora']:
                            record['racha_max'] = racha.get('valor')
                            break
                    else:
                        record['racha_max'] = None

                    # Buscar humedad
                    for hum in day_data.get('humedadRelativa', []):
                        if hum.get('periodo') == record['hora']:
                            record['humedad_relativa'] = hum.get('valor')
                            break
                    else:
                        record['humedad_relativa'] = None
                        
                    hourly_records.append(record)

            # Definir un esquema simple para el DataFrame de Spark
            # NOTA: Este esquema es básico. La estructura real de AEMET es compleja
            # y puede requerir un esquema más detallado o aplanamiento adicional.
            schema = StructType([
                StructField("municipio_id", StringType(), True),
                StructField("nombre_municipio", StringType(), True),
                StructField("provincia", StringType(), True),
                StructField("fecha", StringType(), True),
                StructField("hora", StringType(), True),
                StructField("temperatura", IntegerType(), True),
                StructField("precipitacion", FloatType(), True), # Puede ser decimal (probabilidad) o cantidad
                StructField("dir_viento", StringType(), True),
                StructField("vel_viento", IntegerType(), True),
                StructField("racha_max", IntegerType(), True),
                StructField("humedad_relativa", IntegerType(), True),
            ])

            # Crear el DataFrame de Spark
            spark_df = spark.createDataFrame(hourly_records, schema=schema)
            print(f"DataFrame de Spark creado con {spark_df.count()} filas.")
            return spark_df

        else:
            print("Error: La respuesta inicial de AEMET no contiene la URL de datos ('datos').")
            print(f"Contenido completo de la respuesta inicial: {json.dumps(data_info, indent=2, ensure_ascii=False)}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"¡Error en la solicitud! Ocurrió un problema de red o HTTP: {e}")
        if hasattr(e, 'response') and e.response is not None:
            print(f"Código de estado HTTP: {e.response.status_code}")
            print(f"Contenido de la respuesta de error: {e.response.text}")
        print("Asegúrate de que tu clave API es correcta y tienes conexión a internet.")
        return None
    except json.JSONDecodeError as e:
        print(f"¡Error al procesar la respuesta! La respuesta no es un JSON válido: {e}")
        return None
    except Exception as e:
        print(f"¡Ocurrió un error inesperado!: {e}")
        return None

# --- Ejemplo de Uso en Google Colab ---
if __name__ == '__main__':
    print("--- Obteniendo la Predicción Horaria de Barcelona en un Spark DataFrame ---")
    
    # Llama a la función para obtener el DataFrame
    df_prediccion_horaria = get_aemet_hourly_prediction_as_spark_df(
        api_key=AEMET_API_KEY,
        municipality_code=BARCELONA_MUNICIPALITY_CODE
    )

    if df_prediccion_horaria is not None:
        print("\n--- Esquema del DataFrame ---")
        df_prediccion_horaria.printSchema()

        print("\n--- Primeras filas del DataFrame ---")
        df_prediccion_horaria.show(20) # Muestra las primeras 20 filas

        print("\n--- Estadísticas básicas (temperatura) ---")
        df_prediccion_horaria.select("temperatura", "precipitacion", "humedad_relativa", "vel_viento").summary().show()
        
        # Puedes guardar el DataFrame a un formato como Parquet o CSV
        # df_prediccion_horaria.write.mode("overwrite").parquet("/content/aemet_prediccion_horaria.parquet")
        # print("\nDataFrame guardado en /content/aemet_prediccion_horaria.parquet")
        
        # O realizar operaciones de Spark SQL
        # df_prediccion_horaria.createOrReplaceTempView("prediccion_horaria_barcelona")
        # spark.sql("SELECT fecha, hora, temperatura FROM prediccion_horaria_barcelona WHERE temperatura > 20 ORDER BY fecha, hora").show()
        
    else:
        print("No se pudo crear el DataFrame de Spark con la predicción horaria.")

    # Detener la SparkSession al finalizar si no la necesitas más
    try:
        spark = SparkSession.builder.getOrCreate()
        spark.stop()
        print("\nSparkSession detenida.")
    except Exception:
        pass # La sesión ya estaba detenida o no existía.
# Out:
# --- Obteniendo la Predicción Horaria de Barcelona en un Spark DataFrame ---
# 1. Realizando la primera llamada a la API para el municipio 08019...
# 2. URL de datos obtenida: https://opendata.aemet.es/opendata/sh/051a2dbf
# 3. Obteniendo los datos de predicción horaria...
# SparkSession inicializada.
# ¡Ocurrió un error inesperado!: 'str' object has no attribute 'get'
# No se pudo crear el DataFrame de Spark con la predicción horaria.
#
# SparkSession detenida.
